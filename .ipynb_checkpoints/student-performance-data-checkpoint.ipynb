# %%
library("tidyverse")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
url <- "https://archive.ics.uci.edu/ml/machine-learning-databases/00320/student.zip"
download.file(url, "student.zip")
unzip("student.zip")
student_data <- read_delim("student-por.csv", delim = ";")
student_data
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   age = col_double(),
#   Medu = col_double(),
#   Fedu = col_double(),
#   traveltime = col_double(),
#   studytime = col_double(),
#   failures = col_double(),
#   famrel = col_double(),
#   freetime = col_double(),
#   goout = col_double(),
#   Dalc = col_double(),
#   Walc = col_double(),
#   health = col_double(),
#   absences = col_double(),
#   G1 = col_double(),
#   G2 = col_double(),
#   G3 = col_double()
# )
#
# See spec(...) for full column specifications.
#     school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯ famrel
# 1   GP     F   18  U       GT3     A       4    4    at_home  teacher  ⋯ 4
# 2   GP     F   17  U       GT3     T       1    1    at_home  other    ⋯ 5
# 3   GP     F   15  U       LE3     T       1    1    at_home  other    ⋯ 4
# 4   GP     F   15  U       GT3     T       4    2    health   services ⋯ 3
# 5   GP     F   16  U       GT3     T       3    3    other    other    ⋯ 4
# 6   GP     M   16  U       LE3     T       4    3    services other    ⋯ 5
# 7   GP     M   16  U       LE3     T       2    2    other    other    ⋯ 4
# 8   GP     F   17  U       GT3     A       4    4    other    teacher  ⋯ 4
# 9   GP     M   15  U       LE3     A       3    2    services other    ⋯ 4
# 10  GP     M   15  U       GT3     T       3    4    other    other    ⋯ 5
# 11  GP     F   15  U       GT3     T       4    4    teacher  health   ⋯ 3
# 12  GP     F   15  U       GT3     T       2    1    services other    ⋯ 5
# 13  GP     M   15  U       LE3     T       4    4    health   services ⋯ 4
# 14  GP     M   15  U       GT3     T       4    3    teacher  other    ⋯ 5
# 15  GP     M   15  U       GT3     A       2    2    other    other    ⋯ 4
# 16  GP     F   16  U       GT3     T       4    4    health   other    ⋯ 4
# 17  GP     F   16  U       GT3     T       4    4    services services ⋯ 3
# 18  GP     F   16  U       GT3     T       3    3    other    other    ⋯ 5
# 19  GP     M   17  U       GT3     T       3    2    services services ⋯ 5
# 20  GP     M   16  U       LE3     T       4    3    health   other    ⋯ 3
# 21  GP     M   15  U       GT3     T       4    3    teacher  other    ⋯ 4
# 22  GP     M   15  U       GT3     T       4    4    health   health   ⋯ 5
# 23  GP     M   16  U       LE3     T       4    2    teacher  other    ⋯ 4
# 24  GP     M   16  U       LE3     T       2    2    other    other    ⋯ 5
# 25  GP     F   15  R       GT3     T       2    4    services health   ⋯ 4
# 26  GP     F   16  U       GT3     T       2    2    services services ⋯ 1
# 27  GP     M   15  U       GT3     T       2    2    other    other    ⋯ 4
# 28  GP     M   15  U       GT3     T       4    2    health   services ⋯ 2
# 29  GP     M   16  U       LE3     A       3    4    services other    ⋯ 5
# 30  GP     M   16  U       GT3     T       4    4    teacher  teacher  ⋯ 4
# ⋮   ⋮      ⋮   ⋮   ⋮       ⋮       ⋮       ⋮    ⋮    ⋮        ⋮        ⋱ ⋮
# 620 MS     F   18  U       GT3     T       3    3    services services ⋯ 4
# 621 MS     F   17  U       LE3     T       4    4    at_home  at_home  ⋯ 2
# 622 MS     F   17  R       GT3     T       1    2    other    services ⋯ 3
# 623 MS     M   18  R       GT3     T       1    3    at_home  other    ⋯ 3
# 624 MS     M   18  U       LE3     T       4    4    teacher  services ⋯ 4
# 625 MS     F   17  R       GT3     T       1    1    other    services ⋯ 5
# 626 MS     F   18  U       GT3     T       2    3    at_home  services ⋯ 5
# 627 MS     F   18  R       GT3     T       4    4    other    teacher  ⋯ 3
# 628 MS     M   18  R       LE3     T       1    2    at_home  services ⋯ 4
# 629 MS     F   17  U       GT3     T       2    2    other    at_home  ⋯ 3
# 630 MS     F   17  R       GT3     T       1    2    other    other    ⋯ 3
# 631 MS     F   18  R       LE3     T       4    4    other    other    ⋯ 5
# 632 MS     F   18  R       GT3     T       1    1    other    other    ⋯ 4
# 633 MS     F   19  R       GT3     T       1    1    at_home  other    ⋯ 4
# 634 MS     F   18  R       LE3     T       4    4    teacher  services ⋯ 5
# 635 MS     F   18  U       GT3     T       3    3    other    other    ⋯ 4
# 636 MS     F   17  R       GT3     T       3    1    at_home  other    ⋯ 4
# 637 MS     M   18  U       GT3     T       4    4    teacher  teacher  ⋯ 3
# 638 MS     M   18  R       GT3     T       2    1    other    other    ⋯ 4
# 639 MS     M   17  U       GT3     T       2    3    other    services ⋯ 4
# 640 MS     M   19  R       GT3     T       1    1    other    services ⋯ 4
# 641 MS     M   18  R       GT3     T       4    2    other    other    ⋯ 5
# 642 MS     F   18  R       GT3     T       2    2    at_home  other    ⋯ 5
# 643 MS     F   17  U       GT3     T       4    3    teacher  other    ⋯ 5
# 644 MS     F   18  R       GT3     T       4    4    teacher  at_home  ⋯ 4
# 645 MS     F   19  R       GT3     T       2    3    services other    ⋯ 5
# 646 MS     F   18  U       LE3     T       3    1    teacher  services ⋯ 4
# 647 MS     F   18  U       GT3     T       1    1    other    other    ⋯ 1
# 648 MS     M   17  U       LE3     T       3    1    services services ⋯ 2
# 649 MS     M   18  R       LE3     T       3    2    services other    ⋯ 4
#     freetime goout Dalc Walc health absences G1 G2 G3
# 1   3        4     1    1    3       4        0 11 11
# 2   3        3     1    1    3       2        9 11 11
# 3   3        2     2    3    3       6       12 13 12
# 4   2        2     1    1    5       0       14 14 14
# 5   3        2     1    2    5       0       11 13 13
# 6   4        2     1    2    5       6       12 12 13
# 7   4        4     1    1    3       0       13 12 13
# 8   1        4     1    1    1       2       10 13 13
# 9   2        2     1    1    1       0       15 16 17
# 10  5        1     1    1    5       0       12 12 13
# 11  3        3     1    2    2       2       14 14 14
# 12  2        2     1    1    4       0       10 12 13
# 13  3        3     1    3    5       0       12 13 12
# 14  4        3     1    2    3       0       12 12 13
# 15  5        2     1    1    3       0       14 14 15
# 16  4        4     1    2    2       6       17 17 17
# 17  2        3     1    2    2      10       13 13 14
# 18  3        2     1    1    4       2       13 14 14
# 19  5        5     2    4    5       2        8  8  7
# 20  1        3     1    3    5       6       12 12 12
# 21  4        1     1    1    1       0       12 13 14
# 22  4        2     1    1    5       0       11 12 12
# 23  5        1     1    3    5       0       12 13 14
# 24  4        4     2    4    5       2       10 10 10
# 25  3        2     1    1    5       2       10 11 10
# 26  2        2     1    3    5       6       10 11 12
# 27  2        2     1    2    5       8       11 12 12
# 28  2        4     2    4    1       0       11 11 11
# 29  3        3     1    1    5       2       12 12 13
# 30  4        5     5    5    5       4       12 11 12
# ⋮   ⋮        ⋮     ⋮    ⋮    ⋮      ⋮        ⋮  ⋮  ⋮
# 620 3        2     1    3    3       6       13 12 13
# 621 3        4     1    1    1       4       15 14 15
# 622 2        2     1    2    3       0       13 13 13
# 623 3        4     2    4    3       0        8 10  9
# 624 2        2     2    2    5       0       15 16 16
# 625 2        1     1    2    1       0        8  8  9
# 626 2        3     1    2    4       0       10 10 10
# 627 2        2     4    2    5       0        7  5  0
# 628 3        3     2    3    3       3        9 10 10
# 629 4        3     1    1    3       8       10 11 12
# 630 5        5     1    3    1       4        7  8  9
# 631 4        4     1    1    1       0       15 17 17
# 632 3        2     1    2    4       4       10 11 12
# 633 3        3     1    1    3       4        7  8  9
# 634 4        3     3    4    2       1       13 14 14
# 635 1        3     1    2    1       1       16 16 16
# 636 5        4     2    3    1      10        8  9  9
# 637 2        4     1    4    2       4       17 18 19
# 638 4        3     1    3    5       0        7  7  0
# 639 4        3     1    1    3       4       14 15 16
# 640 3        2     1    3    5       0        5  8  0
# 641 4        3     4    3    3       0        7  7  0
# 642 3        3     1    3    4       0       14 17 15
# 643 5        4     1    1    1       0        6  9 11
# 644 4        3     2    2    5       4        7  9 10
# 645 4        2     1    2    5       4       10 11 10
# 646 3        4     1    1    1       4       15 15 16
# 647 1        1     1    1    5       6       11 12  9
# 648 4        5     3    4    2       6       10 10 10
# 649 4        1     3    4    5       4       10 11 11
